# %%
print("hello, world!")
# Out:
# hello, world!

# %% [markdown]
# just text, first program, maybe doc sidebar)

# %%
class Person:
    def __init__(self, first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name

p = Person("Shavkat", "Bakhtiyarov")

# %% [markdown]
# i can run curtain block of program, not all file, it's a feature
